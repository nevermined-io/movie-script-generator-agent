# %%
# %% [markdown]
# # Payment Data Analysis Dashboard
# 
# This notebook analyzes payment data from specific sessions and creates visualizations using Plotly.
# 
from nb_lib.visualization import *

# %%
def main():
    """Main function to run all visualizations."""
    try:
                
        # Load data
        df = load_payment_data()

        plot_individual_and_cumulative_costs(df)
        cost_summary(df)
        
        # Create visualizations
        # create_summary_statistics(df, output_dir)
        # create_time_series_analysis(df, output_dir)
        # create_agent_analysis(df, output_dir)
        # create_session_analysis(df, output_dir)
        
        print("Open the HTML files in your web browser to view the interactive charts.")
        
    except Exception as e:
        print(f"Error creating dashboard: {e}")

# %%
main()
# Out:
# Looking for payment data files in: /home/nirodha/Desktop/AI/NVM/movie-script-generator-agent/src/data
# Found files: ['/home/nirodha/Desktop/AI/NVM/movie-script-generator-agent/src/data/payment_data_20250528_222713.csv']
# Global Summary:
# Total Cost: 0.00497115
# Average Cost: 0.00099423
# Total Tokens: 16092
# Total Credit Cost: 4.97115
#
# Agent-Specific Summary:
# Agent ID: 39cd3849-c799-ad40-47a9-0a06048fac29
#   Total Cost: 0.00497115
#   Average Cost: 0.00099423
#   Total Tokens: 16092
#   Total Credit Cost: 4.97115
#
# Open the HTML files in your web browser to view the interactive charts.
